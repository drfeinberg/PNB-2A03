# %% [markdown]
# # Assignment 3 - Linear Regression

# %% [markdown]
# ## Your assignment is to write a funtion that will perform an Ordinary Least Squares Regression.
# ### The function should return the slope and the intercept, and a  list of residuals
# ### Test the regression funtion using the simulated data provided below.
#
# The OLS regression equation takes the form:
# $Y_i = b_0 + b_1X_i + \epsilon_i$
#
# #### To code the regression, you need only these 2 formulae
# Slope = $b_0 = $(Σy)(Σx^2) - (Σx)(Σxy)/ n(Σx^2) - (Σx)^2
# Intercept = $b_1= $ n(Σxy) - (Σx)(Σy) /n(Σx^2) - (Σx)^2
#
# Residual = Observed y-value - Predicted y-value
#
# #### Extra credit
# Use the equation for a correlation from last assignment. Make a funciton out of it.  Calculate the $R^2$ value of the regression by squaring the r-value of these data from the correlation equation.

# %% [markdown]
# ## Use this code to simulate your data.  Use `x` and `y` to test your regression.

# %%
import numpy as np

mean = [12, 9]  # These are the means we wrote above
cov = [[1, 0.345], [0.345, 1]] # This is a covariance matrix. 

## Let's pick a sample size of 100
num_samples = 100

## Simulate the data
x, y = np.random.multivariate_normal(mean, cov, size=num_samples).T

print(x)
print(y)
# Out:
# [11.10169541 12.70681748 11.06783311 13.22788263 12.78529999 12.42210481
#  11.34385105 12.52773484 11.07784226 11.106636   13.25925904 10.62235668
#  11.71897199 11.47963652 11.40868816 11.27872993 13.05656808 10.94743844
#  11.35737536 10.89780747 10.6045079  10.41794839 11.04591186 12.96256202
#  11.23423567 11.68934516 11.04863385 11.81001203 11.39823777 11.47320001
#  12.87486131 13.60079852 13.09530272 12.55922041 10.55406959 10.3542185
#  11.09062659 12.55539497  9.71384404 12.02457406 12.17429897 11.10608221
#   9.38184835 12.48568033 11.58539756 13.14021626 10.40492105 10.5580857
#  11.5369579  12.60497124 11.58134483 11.65145817 12.62882638 11.181087
#  12.10785037 12.24300663 11.79477345 12.81089817 11.38487746 11.03048735
#  11.44121474 12.01353577 12.08276949 12.86450787 11.26406488  9.69250272
#   9.21775821 12.97961107 11.70728054 12.16279335 11.4409281  12.42269052
#  12.49430606 11.60664643 12.38441498 12.76101539 11.68699345 11.05068605
#  10.70742881 12.4527879  11.29357014 12.38509259 11.77996847 13.3673238
#  13.10062874 12.24047334 10.76887665 12.35786537 11.9796887  11.6951206
#  11.02111553 13.53643669 11.42295102 13.49835957 11.9286207  12.94477136
#  13.31115776 11.51263648 13.14258528 13.26014191]
# [ 6.66430758  8.33281122  9.43657441  9.93357751  7.91928677  9.5858752
#   9.61773761  8.5709133   9.46563337  8.89990637 10.18689867  7.04478796
#   8.10095533  9.47802296  9.51917475  8.39043377  9.54540522  8.032788
