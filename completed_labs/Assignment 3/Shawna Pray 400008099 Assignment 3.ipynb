# %% [markdown]
# # Assignment 3 - Linear Regression

# %% [markdown]
# ## Your assignment is to write a funtion that will perform an Ordinary Least Squares Regression.
# ### The function should return the slope and the intercept, and a  list of residuals
# ### Test the regression funtion using the simulated data provided below.
#
# The OLS regression equation takes the form:
# $Y_i = b_0 + b_1X_i + \epsilon_i$
#
# #### To code the regression, you need only these 2 formulae
# Slope = $b_0 = $(Σy)(Σx^2) - (Σx)(Σxy)/ n(Σx^2) - (Σx)^2
# Intercept = $b_1= $ n(Σxy) - (Σx)(Σy) /n(Σx^2) - (Σx)^2
#
# Residual = Observed y-value - Predicted y-value
#
# #### Extra credit
# Use the equation for a correlation from last assignment. Make a funciton out of it.  Calculate the $R^2$ value of the regression by squaring the r-value of these data from the correlation equation.

# %% [markdown]
# ## Use this code to simulate your data.  Use `x` and `y` to test your regression.

# %%
import numpy as np

mean = [12, 9]  # These are the means we wrote above
cov = [[1, 0.345], [0.345, 1]] # This is a covariance matrix. 

## Let's pick a sample size of 100
num_samples = 100

## Simulate the data
x, y = np.random.multivariate_normal(mean, cov, size=num_samples).T

print(x)
print(y)
# Out:
# [12.47383008 12.0055831  12.80115836 12.10430327 13.18284518 13.42697557
#  11.58163098 12.80878324 12.78735117 12.98885237 12.33282634  9.98908239
#  11.11132641 12.76678995 11.38935612 11.51619484 11.69144349 12.37106821
#  10.86010157 13.32034556 11.7833496  12.29132901 12.67877147 10.95157225
#  11.76962698 11.59399114 12.07753985 12.87754031 13.20763361 12.85763897
#  11.70089268 11.92034457 12.07530797 10.81778497 10.77099542 12.24140837
#  10.51678552 13.3374781   9.96865335 13.8159585  12.71101427 12.28963444
#  13.66303152 10.2278038  10.7260499  11.74050041 11.96383567 11.64234512
#  11.4549811  11.72723071 11.98146809 12.65907838 11.75705019 11.70464094
#  12.18594738 13.5093711  11.52120884 10.18463021 12.25036488 11.75658475
#  11.68959885 11.05346062 10.65696137 12.57342261  9.92583772 13.55897133
#  12.09508599 13.13077497 12.17818106 11.67440466 12.77819506 12.00974006
#  11.16130312 11.27498233 10.71045048 11.83182288 11.32157392 12.30311999
#  13.73068844  8.5797001  12.55409937 10.51711339 11.66016541 11.07676181
#  13.04721981 11.65655445 11.84773109 11.62652275 12.47956065 11.71465214
#  11.16533747 11.5913345  10.58065331 12.29485739 12.37858444 13.56755981
#  11.4835029  13.74739654 13.51142654 12.39384105]
# [ 9.05961536  8.91480546  8.91500708  8.18647967 10.47252178  9.69799888
#  10.01019495  8.51067878  9.17384484  8.9499588   9.25574327  8.83921549
#  10.02521551  8.50064243  9.57584137  8.21946195  9.75575425  8.97253389
#   7.86567425  8.68170029 10.28490025  8.87238888  9.49041824  8.6103478
#   8.98058922  8.352719    9.92069837  9.86242908  9.87458343  7.99478083
#  10.79890217  8.71943112 10.72692018  8.63583861  8.39299032  8.42484167
