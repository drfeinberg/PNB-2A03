# %% [markdown]
# ## Simulate data for stroop experiment

# %% [markdown]
# # Simulates binary responses.
# - Numpy stands for "number Python" and deals well with the complex math we use in science
# - We are taking random choice from the list `["incorrect", "correct"]`
# - There is a sample size of 50, meaning we take a random choice 50 times
# - We give it a probability `p` which is specified using Python's fraction notation.  Note that the correct and incorrect probabilities are out of 1, but could have been specified differently
# - We'll have more corrects than incorrects in the congruent condition, so we swap the fractions in congrent and incongruent in order to simulate that

# %%
import numpy as np
congruent_responses = np.random.choice(["incorrect", "correct"], size=(50,), p=[1./3, 2./3])
incongruent_responses = np.random.choice(["incorrect", "correct"], size=(50,), p=[2./3, 1./3])

# %%
print(congruent_responses)
print(incongruent_responses)
# Out:
# ['incorrect' 'incorrect' 'correct' 'incorrect' 'correct' 'correct'
#  'correct' 'incorrect' 'correct' 'correct' 'incorrect' 'correct' 'correct'
#  'correct' 'correct' 'incorrect' 'correct' 'correct' 'incorrect'
#  'incorrect' 'correct' 'correct' 'incorrect' 'correct' 'incorrect'
#  'incorrect' 'correct' 'incorrect' 'incorrect' 'correct' 'incorrect'
#  'correct' 'correct' 'incorrect' 'incorrect' 'correct' 'correct' 'correct'
#  'correct' 'incorrect' 'correct' 'incorrect' 'correct' 'correct' 'correct'
#  'incorrect' 'incorrect' 'correct' 'correct' 'incorrect']
# ['correct' 'incorrect' 'incorrect' 'correct' 'correct' 'incorrect'
#  'incorrect' 'correct' 'incorrect' 'incorrect' 'incorrect' 'correct'
#  'correct' 'correct' 'correct' 'incorrect' 'correct' 'incorrect'
#  'incorrect' 'correct' 'incorrect' 'incorrect' 'correct' 'incorrect'
#  'correct' 'correct' 'correct' 'correct' 'incorrect' 'correct' 'incorrect'
#  'correct' 'incorrect' 'incorrect' 'incorrect' 'incorrect' 'incorrect'
#  'incorrect' 'incorrect' 'correct' 'incorrect' 'incorrect' 'incorrect'
#  'correct' 'incorrect' 'incorrect' 'correct' 'correct' 'correct'
#  'incorrect']

# %%
proportion_correct = np.count_nonzero(congruent_responses == "correct")
number_correct
# Out:
# 17

# %% [markdown]
# ## Simulate reaction time data

# %%
import random

a = 0.005 # lowest possible reaction time
b = 6 # highest possible reaction time
x = 2.5 # mode of reaction time
reaction_time = random.triangular(a, b, 3*x - a - b)
reaction_time
# Out:
# 1.6968456909774687

# %% [markdown]
# ### Add that to our program

# %%
import numpy as np
import pandas as pd
import random


number_of_participants = 1000
a = 0.005 # lowest possible reaction time
b = 6 # highest possible reaction time
x = 2.5 # mode of reaction time


data = []

for i in range(number_of_participants):
    condition = "congruent"
    congruent_responses = np.random.choice(["incorrect", "correct"], size=(50,), p=[1./3, 2./3])  # generate responses to 50 congruent stimuli for each person
    x = 1 # mode of reaction time is lower here than in incongruent to simulate faster reactions
    reaction_time = random.triangular(a, b, 3*x - a - b)
    participant = i + 1000
    data_dictionary = {
        "participant": participant,
        "condition": condition,
        "response_correct": congruent_responses,
        "reaction_time": reaction_time
    }
    data.append(data_dictionary)
    condition = "incongruent"
    incongruent_responses = np.random.choice(["incorrect", "correct"], size=(50,), p=[2./3, 1./3]) # generate responses to 50 incongruent stimuli for each person
    x = 3 # mode of reaction time is higher here than in incongruent to simulate slower reactions
    reaction_time = random.triangular(a, b, 3*x - a - b)
    data_dictionary = {
        "participant": participant,
        "condition": condition,
        "response_correct": incongruent_responses,
        "reaction_time": reaction_time
    }
    data.append(data_dictionary)

# %%
data
# Out:
# [{'participant': 1000,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.1312073446991056},
#  {'participant': 1000,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.1886745017555382},
#  {'participant': 1001,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 0.07415135552320073},
#  {'participant': 1001,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.134743260763768},
#  {'participant': 1002,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 0.847994313103575},
#  {'participant': 1002,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 1.3620357443870408},
#  {'participant': 1003,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 0.38538510655332026},
#  {'participant': 1003,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.465600966294144},
#  {'participant': 1004,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': -0.4096763592240231},
#  {'participant': 1004,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 0.5338395688377318},
#  {'participant': 1005,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 4.878223346567549},
#  {'participant': 1005,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.9205504875997},
#  {'participant': 1006,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 0.5334977304546333},
#  {'participant': 1006,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 3.862959047213986},
#  {'participant': 1007,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct'], dtype='<U9'),
#   'reaction_time': -0.8774121380814393},
#  {'participant': 1007,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 2.754991854716478},
#  {'participant': 1008,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': -0.8013160299320496},
#  {'participant': 1008,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 0.23839235224264962},
#  {'participant': 1009,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': -0.673039686451431},
#  {'participant': 1009,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 3.7230084543783204},
#  {'participant': 1010,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect'], dtype='<U9'),
#   'reaction_time': -1.0058171706291015},
#  {'participant': 1010,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 0.8256509250930304},
#  {'participant': 1011,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 3.4234625656416378},
#  {'participant': 1011,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 1.9477112624199067},
#  {'participant': 1012,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct'], dtype='<U9'),
#   'reaction_time': 0.6176923903684175},
#  {'participant': 1012,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 4.194934672443029},
#  {'participant': 1013,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect'], dtype='<U9'),
#   'reaction_time': 1.4653081219883788},
#  {'participant': 1013,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 4.609210111746771},
#  {'participant': 1014,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': -0.5225085635516082},
#  {'participant': 1014,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.481973806377791},
#  {'participant': 1015,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct'], dtype='<U9'),
#   'reaction_time': -0.7062254380283299},
#  {'participant': 1015,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.595086070621701},
#  {'participant': 1016,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 1.003945412205364},
#  {'participant': 1016,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 1.6961103204197754},
#  {'participant': 1017,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 1.7398591293420163},
#  {'participant': 1017,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 3.40266376970386},
#  {'participant': 1018,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 0.7959622790462362},
#  {'participant': 1018,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 5.802477114646496},
#  {'participant': 1019,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct'], dtype='<U9'),
#   'reaction_time': 2.770459762540981},
#  {'participant': 1019,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 4.076065226948181},
#  {'participant': 1020,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': -0.7593186671665286},
#  {'participant': 1020,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 1.959444309079566},
#  {'participant': 1021,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 5.100433117891548},
#  {'participant': 1021,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 2.3329110111836857},
#  {'participant': 1022,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 1.849670359229867},
#  {'participant': 1022,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.194504444124203},
#  {'participant': 1023,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 3.4163476209343937},
#  {'participant': 1023,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 3.4138450472579693},
#  {'participant': 1024,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct'], dtype='<U9'),
#   'reaction_time': -1.3317162861612992},
#  {'participant': 1024,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.475392816956731},
#  {'participant': 1025,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 1.8251070339360096},
#  {'participant': 1025,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 2.6972805985202677},
#  {'participant': 1026,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 0.2649323402974},
#  {'participant': 1026,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.658762398617842},
#  {'participant': 1027,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect'], dtype='<U9'),
#   'reaction_time': -0.7123648666346538},
#  {'participant': 1027,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 3.568098989326529},
#  {'participant': 1028,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 2.364955790803125},
#  {'participant': 1028,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.357032915768341},
#  {'participant': 1029,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
# ...
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 4.0898723790895115},
#  {'participant': 1490,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 3.9002044016659703},
#  {'participant': 1491,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 4.048813907298674},
#  {'participant': 1491,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 2.9611253619484548},
#  {'participant': 1492,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct'], dtype='<U9'),
#   'reaction_time': 2.017876922032384},
#  {'participant': 1492,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 3.561527468318982},
#  {'participant': 1493,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct'],
#         dtype='<U9'),
#   'reaction_time': -0.45998073145215823},
#  {'participant': 1493,
#   'condition': 'incongruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 3.7962630179355457},
#  {'participant': 1494,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 1.289179127984073},
#  {'participant': 1494,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect'], dtype='<U9'),
#   'reaction_time': 3.3006976150017904},
#  {'participant': 1495,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect'], dtype='<U9'),
#   'reaction_time': 3.9546212968689725},
#  {'participant': 1495,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 2.479516578407334},
#  {'participant': 1496,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'correct', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': -0.08543436641062829},
#  {'participant': 1496,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.7775204275628504},
#  {'participant': 1497,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 2.5874150420226614},
#  {'participant': 1497,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'correct', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 4.137087629363512},
#  {'participant': 1498,
#   'condition': 'congruent',
#   'response_correct': array(['correct', 'incorrect', 'correct', 'correct', 'incorrect',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'correct', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': -0.0324429670042079},
#  {'participant': 1498,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect'],
#         dtype='<U9'),
#   'reaction_time': 2.2257547130094446},
#  {'participant': 1499,
#   'condition': 'congruent',
#   'response_correct': array(['incorrect', 'correct', 'correct', 'correct', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'correct', 'correct', 'correct',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'correct', 'correct', 'correct', 'correct', 'correct',
#          'correct', 'incorrect', 'correct', 'incorrect', 'correct',
#          'correct', 'incorrect', 'incorrect', 'correct'], dtype='<U9'),
#   'reaction_time': 0.7972397890646752},
#  {'participant': 1499,
#   'condition': 'incongruent',
#   'response_correct': array(['incorrect', 'incorrect', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'incorrect', 'incorrect', 'incorrect', 'correct', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'correct', 'correct', 'correct', 'incorrect', 'incorrect',
#          'correct', 'incorrect', 'correct', 'incorrect', 'incorrect',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct',
#          'incorrect', 'correct', 'incorrect', 'incorrect', 'correct'],
#         dtype='<U9'),
#   'reaction_time': 3.584619918406196},
#  ...]

# %% [markdown]
# # Pandas DataFrame
# A Pandas DataFrame is a Python Object that holds a set of data like a spreadsheet.

# %%
import pandas as pd  # it is custom to shorten pandas to pd because we'll be typing it a log
df = pd.DataFrame(data=data)  # called the dataframe df, but you can use any name you want... it's a Python object.

# %% [markdown]
# You can view the whole DataFrame by typing `df` as usual.  But, perhaps your dataset is large and you just want to get a sense of how it's looking.  For that we can use the `head()` method call on our dataframe.  By default it shows the first 5 rows, or you can specify the number of rows you want to see.

# %%
df.head()
# Out:
#      condition  participant  reaction_time  \
# 0    congruent         1000       2.131207
# 1  incongruent         1000       2.188675
# 2    congruent         1001       0.074151
# 3  incongruent         1001       2.134743
# 4    congruent         1002       0.847994
#
#                                     response_correct
# 0  [incorrect, correct, correct, correct, correct...
# 1  [incorrect, incorrect, correct, incorrect, inc...
# 2  [correct, correct, correct, correct, correct, ...
# 3  [correct, incorrect, incorrect, incorrect, cor...
# 4  [correct, correct, correct, incorrect, correct...

# %%
df.head(2)
# Out:
#      condition  participant  reaction_time  \
# 0    congruent         1000       2.131207
# 1  incongruent         1000       2.188675
#
#                                     response_correct
# 0  [incorrect, correct, correct, correct, correct...
# 1  [incorrect, incorrect, correct, incorrect, inc...

# %%
for col in df.columns: 
    print(col)
# Out:
# condition
# participant
# reaction_time
# response_correct

# %%
df.head(10)
# Out:
#      condition  participant  reaction_time  \
# 0    congruent         1000       2.131207
# 1  incongruent         1000       2.188675
# 2    congruent         1001       0.074151
# 3  incongruent         1001       2.134743
# 4    congruent         1002       0.847994
# 5  incongruent         1002       1.362036
# 6    congruent         1003       0.385385
# 7  incongruent         1003       4.465601
# 8    congruent         1004      -0.409676
# 9  incongruent         1004       0.533840
#
#                                     response_correct
# 0  [incorrect, correct, correct, correct, correct...
# 1  [incorrect, incorrect, correct, incorrect, inc...
# 2  [correct, correct, correct, correct, correct, ...
# 3  [correct, incorrect, incorrect, incorrect, cor...
# 4  [correct, correct, correct, incorrect, correct...
# 5  [incorrect, incorrect, incorrect, correct, inc...
# 6  [incorrect, correct, incorrect, incorrect, cor...
# 7  [correct, incorrect, correct, incorrect, incor...
# 8  [correct, correct, correct, correct, correct, ...
# 9  [incorrect, correct, correct, correct, incorre...

# %% [markdown]
# Ack! our `response_correct` column has a Python list in it.  We wanted each response to be in it's own column.  That's okay.   We'll use the `apply` method on the `response_correct` column and turn the list into a series.

# %%
responses = df['response_correct'].apply(pd.Series)

# %% [markdown]
# Then we concatenate, or put the two dataframes together

# %%
df = pd.concat([df, responses], axis=1)
df.head()
# Out:
#      condition  participant  reaction_time  \
# 0    congruent         1000       2.131207
# 1  incongruent         1000       2.188675
# 2    congruent         1001       0.074151
# 3  incongruent         1001       2.134743
# 4    congruent         1002       0.847994
#
#                                     response_correct          0          1  \
# 0  [incorrect, correct, correct, correct, correct...  incorrect    correct
# 1  [incorrect, incorrect, correct, incorrect, inc...  incorrect  incorrect
# 2  [correct, correct, correct, correct, correct, ...    correct    correct
# 3  [correct, incorrect, incorrect, incorrect, cor...    correct  incorrect
# 4  [correct, correct, correct, incorrect, correct...    correct    correct
#
#            2          3          4          5  ...         40         41  \
# 0    correct    correct    correct    correct  ...  incorrect    correct
# 1    correct  incorrect  incorrect  incorrect  ...    correct  incorrect
# 2    correct    correct    correct  incorrect  ...    correct    correct
# 3  incorrect  incorrect    correct    correct  ...  incorrect  incorrect
# 4    correct  incorrect    correct    correct  ...    correct    correct
#
#           42         43         44         45         46         47  \
# 0    correct    correct  incorrect    correct    correct    correct
# 1    correct    correct  incorrect  incorrect  incorrect  incorrect
# 2    correct  incorrect    correct  incorrect  incorrect  incorrect
# 3  incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 4    correct    correct    correct    correct    correct    correct
#
#           48         49
# 0    correct  incorrect
# 1  incorrect  incorrect
# 2  incorrect    correct
# 3    correct  incorrect
# 4    correct    correct
#
# [5 rows x 54 columns]

# %% [markdown]
# Clean up by removing numpy array

# %%
df = df.drop('response_correct', axis=1)

# %%
df.head()
# Out:
#      condition  participant  reaction_time          0          1          2  \
# 0    congruent         1000       2.131207  incorrect    correct    correct
# 1  incongruent         1000       2.188675  incorrect  incorrect    correct
# 2    congruent         1001       0.074151    correct    correct    correct
# 3  incongruent         1001       2.134743    correct  incorrect  incorrect
# 4    congruent         1002       0.847994    correct    correct    correct
#
#            3          4          5          6  ...         40         41  \
# 0    correct    correct    correct    correct  ...  incorrect    correct
# 1  incorrect  incorrect  incorrect    correct  ...    correct  incorrect
# 2    correct    correct  incorrect  incorrect  ...    correct    correct
# 3  incorrect    correct    correct  incorrect  ...  incorrect  incorrect
# 4  incorrect    correct    correct    correct  ...    correct    correct
#
#           42         43         44         45         46         47  \
# 0    correct    correct  incorrect    correct    correct    correct
# 1    correct    correct  incorrect  incorrect  incorrect  incorrect
# 2    correct  incorrect    correct  incorrect  incorrect  incorrect
# 3  incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 4    correct    correct    correct    correct    correct    correct
#
#           48         49
# 0    correct  incorrect
# 1  incorrect  incorrect
# 2  incorrect    correct
# 3    correct  incorrect
# 4    correct    correct
#
# [5 rows x 53 columns]

# %% [markdown]
# We can access our columns with data using slice notation

# %%
df.iloc[:, 3:53]
# Out:
#              0          1          2          3          4          5   \
# 0     incorrect    correct    correct    correct    correct    correct
# 1     incorrect  incorrect    correct  incorrect  incorrect  incorrect
# 2       correct    correct    correct    correct    correct  incorrect
# 3       correct  incorrect  incorrect  incorrect    correct    correct
# 4       correct    correct    correct  incorrect    correct    correct
# 5     incorrect  incorrect  incorrect    correct  incorrect    correct
# 6     incorrect    correct  incorrect  incorrect    correct    correct
# 7       correct  incorrect    correct  incorrect  incorrect  incorrect
# 8       correct    correct    correct    correct    correct    correct
# 9     incorrect    correct    correct    correct  incorrect    correct
# 10    incorrect  incorrect    correct    correct    correct    correct
# 11      correct  incorrect    correct  incorrect  incorrect  incorrect
# 12      correct    correct  incorrect  incorrect    correct    correct
# 13    incorrect    correct  incorrect  incorrect    correct  incorrect
# 14      correct    correct    correct    correct    correct    correct
# 15    incorrect  incorrect  incorrect    correct  incorrect  incorrect
# 16    incorrect    correct  incorrect    correct  incorrect    correct
# 17    incorrect  incorrect  incorrect  incorrect    correct  incorrect
# 18      correct    correct  incorrect  incorrect    correct    correct
# 19    incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 20      correct    correct  incorrect    correct  incorrect    correct
# 21    incorrect  incorrect  incorrect  incorrect    correct    correct
# 22    incorrect  incorrect  incorrect    correct    correct    correct
# 23    incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 24      correct  incorrect  incorrect    correct    correct    correct
# 25      correct  incorrect  incorrect  incorrect  incorrect    correct
# 26    incorrect    correct  incorrect    correct    correct    correct
# 27      correct  incorrect  incorrect  incorrect  incorrect  incorrect
# 28      correct    correct  incorrect  incorrect    correct    correct
# 29    incorrect    correct  incorrect  incorrect  incorrect    correct
# ...         ...        ...        ...        ...        ...        ...
# 1970    correct    correct  incorrect    correct  incorrect    correct
# 1971  incorrect    correct  incorrect  incorrect    correct    correct
# 1972  incorrect    correct    correct    correct    correct  incorrect
# 1973  incorrect    correct  incorrect  incorrect    correct  incorrect
# 1974  incorrect  incorrect    correct  incorrect    correct    correct
# 1975  incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 1976  incorrect    correct  incorrect    correct  incorrect    correct
# 1977  incorrect  incorrect  incorrect    correct    correct    correct
# 1978    correct    correct    correct  incorrect    correct    correct
# 1979  incorrect  incorrect  incorrect  incorrect    correct  incorrect
# 1980    correct    correct    correct    correct  incorrect    correct
# 1981  incorrect    correct    correct  incorrect  incorrect    correct
# 1982    correct  incorrect    correct    correct  incorrect    correct
# 1983    correct  incorrect  incorrect  incorrect  incorrect    correct
# 1984  incorrect    correct  incorrect    correct    correct    correct
# 1985  incorrect  incorrect    correct  incorrect  incorrect  incorrect
# 1986  incorrect    correct    correct    correct    correct    correct
# 1987  incorrect  incorrect  incorrect    correct  incorrect  incorrect
# 1988  incorrect    correct    correct    correct    correct    correct
# 1989  incorrect  incorrect    correct  incorrect  incorrect    correct
# 1990  incorrect  incorrect    correct    correct  incorrect    correct
# 1991    correct  incorrect  incorrect  incorrect  incorrect    correct
# 1992  incorrect    correct  incorrect    correct  incorrect  incorrect
# 1993  incorrect    correct    correct  incorrect    correct    correct
# 1994    correct    correct    correct    correct  incorrect  incorrect
# 1995  incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 1996    correct  incorrect  incorrect    correct    correct    correct
# 1997  incorrect  incorrect  incorrect  incorrect  incorrect  incorrect
# 1998    correct    correct  incorrect    correct  incorrect  incorrect
# 1999  incorrect  incorrect  incorrect  incorrect    correct  incorrect
#
#              6          7          8          9   ...         40         41  \
# 0       correct  incorrect    correct    correct  ...  incorrect    correct
# 1       correct    correct  incorrect  incorrect  ...    correct  incorrect
# 2     incorrect  incorrect    correct    correct  ...    correct    correct
# 3     incorrect  incorrect    correct  incorrect  ...  incorrect  incorrect
# 4       correct    correct    correct  incorrect  ...    correct    correct
# 5     incorrect  incorrect    correct  incorrect  ...  incorrect  incorrect
# 6       correct    correct    correct  incorrect  ...    correct    correct
# 7       correct    correct    correct  incorrect  ...  incorrect    correct
# 8       correct  incorrect  incorrect  incorrect  ...    correct    correct
# 9     incorrect  incorrect  incorrect  incorrect  ...  incorrect    correct
# 10      correct    correct    correct  incorrect  ...    correct    correct
# 11    incorrect  incorrect    correct  incorrect  ...  incorrect  incorrect
# 12    incorrect    correct    correct  incorrect  ...  incorrect    correct
# 13    incorrect  incorrect    correct    correct  ...  incorrect    correct
# 14      correct    correct  incorrect  incorrect  ...    correct    correct
# 15      correct  incorrect  incorrect  incorrect  ...    correct    correct
# 16    incorrect  incorrect    correct  incorrect  ...  incorrect    correct
# 17    incorrect  incorrect    correct    correct  ...  incorrect  incorrect
# 18      correct    correct    correct    correct  ...    correct    correct
# 19    incorrect  incorrect    correct  incorrect  ...  incorrect  incorrect
# 20    incorrect    correct    correct    correct  ...  incorrect  incorrect
# 21      correct  incorrect    correct  incorrect  ...    correct  incorrect
# 22      correct  incorrect    correct    correct  ...    correct    correct
# 23    incorrect    correct  incorrect  incorrect  ...  incorrect  incorrect
# 24      correct    correct    correct    correct  ...  incorrect  incorrect
# 25    incorrect  incorrect  incorrect  incorrect  ...    correct  incorrect
# 26    incorrect    correct    correct    correct  ...    correct  incorrect
# 27      correct  incorrect    correct    correct  ...  incorrect  incorrect
# 28    incorrect    correct  incorrect    correct  ...    correct    correct
# 29    incorrect    correct  incorrect  incorrect  ...    correct  incorrect
# ...         ...        ...        ...        ...  ...        ...        ...
# 1970    correct    correct    correct    correct  ...  incorrect  incorrect
# 1971  incorrect  incorrect  incorrect  incorrect  ...  incorrect    correct
# 1972    correct    correct    correct    correct  ...    correct  incorrect
# 1973  incorrect  incorrect  incorrect  incorrect  ...    correct  incorrect
# 1974    correct  incorrect    correct    correct  ...  incorrect  incorrect
# 1975    correct  incorrect    correct    correct  ...  incorrect    correct
# 1976    correct    correct  incorrect    correct  ...    correct    correct
# 1977  incorrect    correct  incorrect  incorrect  ...    correct  incorrect
# 1978    correct  incorrect  incorrect    correct  ...    correct    correct
# 1979    correct    correct  incorrect  incorrect  ...  incorrect  incorrect
# 1980    correct    correct  incorrect  incorrect  ...  incorrect    correct
# 1981    correct  incorrect  incorrect  incorrect  ...  incorrect  incorrect
# 1982    correct    correct    correct  incorrect  ...    correct    correct
# 1983  incorrect    correct    correct  incorrect  ...    correct    correct
# 1984    correct    correct    correct    correct  ...  incorrect  incorrect
# 1985  incorrect    correct  incorrect  incorrect  ...  incorrect  incorrect
# 1986  incorrect    correct  incorrect    correct  ...    correct    correct
# 1987  incorrect  incorrect  incorrect  incorrect  ...  incorrect  incorrect
# 1988  incorrect    correct    correct  incorrect  ...    correct  incorrect
# 1989    correct  incorrect  incorrect  incorrect  ...  incorrect    correct
# 1990    correct    correct    correct    correct  ...    correct  incorrect
# 1991    correct  incorrect  incorrect  incorrect  ...  incorrect  incorrect
# 1992    correct  incorrect    correct    correct  ...    correct  incorrect
# 1993  incorrect    correct  incorrect  incorrect  ...  incorrect  incorrect
# 1994  incorrect    correct    correct  incorrect  ...    correct    correct
# 1995  incorrect  incorrect  incorrect    correct  ...  incorrect    correct
# 1996    correct  incorrect    correct  incorrect  ...    correct  incorrect
# 1997  incorrect    correct  incorrect    correct  ...    correct  incorrect
# 1998  incorrect  incorrect  incorrect    correct  ...  incorrect    correct
# 1999    correct    correct  incorrect  incorrect  ...  incorrect    correct
#
#              42         43         44         45         46         47  \
# 0       correct    correct  incorrect    correct    correct    correct
# 1       correct    correct  incorrect  incorrect  incorrect  incorrect
# 2       correct  incorrect    correct  incorrect  incorrect  incorrect
# 3     incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 4       correct    correct    correct    correct    correct    correct
# 5       correct    correct  incorrect    correct  incorrect  incorrect
# 6     incorrect    correct    correct  incorrect  incorrect    correct
# 7     incorrect    correct    correct  incorrect  incorrect    correct
# 8     incorrect    correct    correct    correct    correct  incorrect
# 9     incorrect  incorrect  incorrect  incorrect  incorrect  incorrect
# 10    incorrect    correct    correct  incorrect  incorrect    correct
# 11      correct  incorrect  incorrect  incorrect  incorrect    correct
# 12    incorrect    correct    correct    correct  incorrect  incorrect
# 13    incorrect  incorrect    correct  incorrect  incorrect  incorrect
# 14      correct    correct    correct  incorrect    correct    correct
# 15      correct  incorrect  incorrect  incorrect  incorrect    correct
# 16      correct  incorrect    correct    correct  incorrect    correct
# 17    incorrect  incorrect  incorrect  incorrect  incorrect  incorrect
# 18      correct  incorrect  incorrect    correct  incorrect  incorrect
# 19    incorrect  incorrect    correct  incorrect  incorrect    correct
# 20    incorrect    correct    correct    correct  incorrect    correct
# 21    incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 22    incorrect    correct  incorrect    correct  incorrect  incorrect
# 23      correct  incorrect  incorrect    correct  incorrect    correct
# 24      correct    correct    correct    correct    correct    correct
# 25      correct  incorrect    correct  incorrect  incorrect  incorrect
# 26      correct    correct    correct    correct  incorrect  incorrect
# 27      correct  incorrect  incorrect  incorrect    correct    correct
# 28    incorrect    correct    correct    correct    correct  incorrect
# 29    incorrect  incorrect  incorrect    correct    correct    correct
# ...         ...        ...        ...        ...        ...        ...
# 1970    correct    correct    correct  incorrect    correct    correct
# 1971  incorrect  incorrect    correct  incorrect  incorrect    correct
# 1972  incorrect  incorrect    correct  incorrect    correct    correct
# 1973  incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 1974    correct  incorrect    correct    correct    correct  incorrect
# 1975    correct  incorrect  incorrect  incorrect  incorrect  incorrect
# 1976    correct    correct    correct    correct  incorrect    correct
# 1977  incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 1978    correct  incorrect    correct  incorrect  incorrect    correct
# 1979  incorrect  incorrect  incorrect  incorrect  incorrect    correct
# 1980    correct    correct    correct    correct  incorrect    correct
# 1981  incorrect    correct    correct  incorrect    correct    correct
# 1982    correct    correct  incorrect    correct  incorrect    correct
# 1983    correct  incorrect  incorrect    correct  incorrect    correct
# 1984    correct  incorrect  incorrect    correct    correct    correct
# 1985  incorrect  incorrect    correct  incorrect  incorrect  incorrect
# 1986    correct    correct  incorrect    correct    correct    correct
# 1987  incorrect  incorrect  incorrect  incorrect    correct    correct
# 1988    correct  incorrect    correct    correct  incorrect    correct
# 1989  incorrect  incorrect    correct  incorrect    correct    correct
# 1990    correct    correct    correct  incorrect  incorrect  incorrect
# 1991  incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 1992  incorrect    correct  incorrect    correct    correct    correct
# 1993  incorrect  incorrect    correct    correct  incorrect    correct
# 1994    correct    correct    correct  incorrect    correct  incorrect
# 1995    correct  incorrect    correct  incorrect    correct  incorrect
# 1996  incorrect    correct    correct  incorrect    correct    correct
# 1997  incorrect  incorrect  incorrect  incorrect  incorrect  incorrect
# 1998  incorrect    correct    correct    correct  incorrect  incorrect
# 1999  incorrect    correct  incorrect  incorrect  incorrect  incorrect
#
#              48         49
# 0       correct  incorrect
# 1     incorrect  incorrect
# 2     incorrect    correct
# 3       correct  incorrect
# 4       correct    correct
# 5     incorrect  incorrect
# 6       correct    correct
# 7     incorrect  incorrect
# 8     incorrect    correct
# 9     incorrect  incorrect
# 10    incorrect  incorrect
# 11    incorrect  incorrect
# 12    incorrect    correct
# 13      correct  incorrect
# 14    incorrect    correct
# 15    incorrect    correct
# 16      correct  incorrect
# 17    incorrect  incorrect
# 18      correct  incorrect
# 19      correct    correct
# 20      correct  incorrect
# 21      correct    correct
# 22      correct    correct
# 23    incorrect    correct
# 24      correct    correct
# 25    incorrect  incorrect
# 26      correct  incorrect
# 27    incorrect    correct
# 28      correct    correct
# 29    incorrect  incorrect
# ...         ...        ...
# 1970    correct    correct
# 1971    correct    correct
# 1972    correct  incorrect
# 1973  incorrect    correct
# 1974  incorrect  incorrect
# 1975    correct  incorrect
# 1976  incorrect  incorrect
# 1977    correct  incorrect
# 1978    correct    correct
# 1979  incorrect    correct
# 1980    correct    correct
# 1981    correct  incorrect
# 1982    correct    correct
# 1983  incorrect    correct
# 1984    correct    correct
# 1985    correct  incorrect
# 1986  incorrect    correct
# 1987  incorrect    correct
# 1988  incorrect    correct
# 1989  incorrect  incorrect
# 1990  incorrect    correct
# 1991  incorrect  incorrect
# 1992  incorrect    correct
# 1993    correct  incorrect
# 1994  incorrect    correct
# 1995    correct  incorrect
# 1996    correct    correct
# 1997  incorrect  incorrect
# 1998    correct  incorrect
# 1999  incorrect  incorrect
#
# [2000 rows x 50 columns]

# %% [markdown]
# Then we can calculate proportion correct by applying a conditional count method.

# %%
df['proportion_correct'] = df[df.iloc[:, 3:53] == "correct"].count(axis=1) / 50
df.head()
# Out:
#      condition  participant  reaction_time          0          1          2  \
# 0    congruent         1000       2.131207  incorrect    correct    correct
# 1  incongruent         1000       2.188675  incorrect  incorrect    correct
# 2    congruent         1001       0.074151    correct    correct    correct
# 3  incongruent         1001       2.134743    correct  incorrect  incorrect
# 4    congruent         1002       0.847994    correct    correct    correct
#
#            3          4          5          6  ...         41         42  \
# 0    correct    correct    correct    correct  ...    correct    correct
# 1  incorrect  incorrect  incorrect    correct  ...  incorrect    correct
# 2    correct    correct  incorrect  incorrect  ...    correct    correct
# 3  incorrect    correct    correct  incorrect  ...  incorrect  incorrect
# 4  incorrect    correct    correct    correct  ...    correct    correct
#
#           43         44         45         46         47         48  \
# 0    correct  incorrect    correct    correct    correct    correct
# 1    correct  incorrect  incorrect  incorrect  incorrect  incorrect
# 2  incorrect    correct  incorrect  incorrect  incorrect  incorrect
# 3  incorrect  incorrect  incorrect  incorrect    correct    correct
# 4    correct    correct    correct    correct    correct    correct
#
#           49 proportion_correct
# 0  incorrect               0.74
# 1  incorrect               0.28
# 2    correct               0.66
# 3  incorrect               0.26
# 4    correct               0.70
#
# [5 rows x 54 columns]
